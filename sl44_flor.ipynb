# %%
import pandas as pd
import os

# %%
import numpy as np

# %%
fp1 = r'C:\Users\HP PRO\Desktop\Python\SL44_APAC_TSM.xls'
fp2= r'C:\Users\HP PRO\Desktop\Python\SL44_APAC_AVAMAR.xls'

# %%
file_a = pd.read_excel(fp1)
file_t = pd.read_excel(fp2)

# %%
file_a.shape
# Out:
# (4903, 9)

# %%
file_t.shape
# Out:
# (2499, 9)

# %%
4903+2499
# Out:
# 7402

# %%
file_a.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
file_t.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup re-run(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
set(SL44_APAC_TSM.columns) - set(SL44_APAC_AVAMAR.columns)
# Out:
# set()

# %%
SL44_APAC_TSM.columns = SL44_APAC_AVAMAR.columns

# %%
set(.columns) - set(file_t.columns)
# Out:
# set()

# %%
final_file1 = pd.concat([file_a,file_t],ignore_index=True)

# %%
final_file1.to_excel("Final_file1.xlsx",index=False)

# %%
SL44_SA_TSM.drop(['SiteCode','ScheduleName','Duration(HH:MM:SS)','DataTransfered(MB)','Performance(B/Sec)'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-858307a31e48> in <module>
# ----> 1 SL44_SA_TSM.drop(['SiteCode','ScheduleName','Duration(HH:MM:SS)','DataTransfered(MB)','Performance(B/Sec)'],axis=1,inplace=True)
#
# NameError: name 'SL44_SA_TSM' is not defined

# %%
SL44_EMEA_TSM.drop(['SiteCode','ScheduleName','Duration(HH:MM:SS)','DataTransfered(MB)','Performance(B/Sec)'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-cb489ad54805> in <module>
# ----> 1 SL44_EMEA_TSM.drop(['SiteCode','ScheduleName','Duration(HH:MM:SS)','DataTransfered(MB)','Performance(B/Sec)'],axis=1,inplace=True)
#       2
#       3
#
# NameError: name 'SL44_EMEA_TSM' is not defined

# %%
EMEA_AVAMAR1 = pd.read_excel(r"C:\Users\HP PRO\Desktop\Python\Office_work\EMEANES\Backup_Report_EMEA_NES_20200531.xls",1)
EMEA_AVAMAR1.to_excel("EMEA_AVAMAR_0031.xls",index=False)

# %%
path = "./Office_work/EMEA"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

SL44_EMEA_AVAMAR = pd.DataFrame()

for file in files:
    current_data = pd.read_excel(path+"/"+file)
    SL44_EMEA_AVAMAR = pd.concat([SL44_EMEA_AVAMAR, current_data])
    
SL44_EMEA_AVAMAR.to_excel("SL44_EMEA_AVAMAR.xls", index=False)

# %%
SL44_EMEA_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDateTime', 'ClientName', 'Level',
#        'Outcome', 'Backup re-run', 'Reason', 'Final outcome'],
#       dtype='object')

# %%
SL44_EMEA_AVAMAR.drop(['GroupName','Duration(HH:MM:SS)','DataTransferredKB','Performance(MB/sec)'],axis=1,inplace=True)

# %%
SL44_EMEA_AVAMAR.rename(columns={'BackupServer':'BackupServer','BackupDay':'BackupDay','StartDateTime':'StartDate','ClientName':'ClientName','Outcome':'BackupStatus','Backup re-run':'Backup Rerun(Y/N)','Reason':'Reason for the Backup Failures','Final outcome':'Backup Final Outcome'},inplace=True)

# %%
SL44_EMEA_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'Level',
#        'BackupStatus', 'Backup Rerun(Y/N)', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
pd.read_excel('SL44_EMEA_TSM.xls')
# Out:
#               BackupServer  BackupDay        StartDateTime        Level  \
# 0     FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 20:00:55  Incremental
# 1     FBSIBAK003.FDNET.COM 2020-05-01  2020-05-01 03:30:15        Other
# 2     FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 23:30:20        Other
# 3     FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 23:30:21        Other
# 4     FBSIBAK003.FDNET.COM 2020-05-01  2020-05-01 03:30:07        Other
# ...                    ...        ...                  ...          ...
# 9897            fnpiaun001 2020-05-31  2020-05-30 17:42:46  Incremental
# 9898  kvsibak002.fdnet.com 2020-05-31  2020-05-30 20:00:44  Incremental
# 9899            ukpiaun001 2020-05-31  2020-05-30 19:14:30  Incremental
# 9900  kvsibak002.fdnet.com 2020-05-31  2020-05-31 02:00:45         Full
# 9901  kvsibak002.fdnet.com 2020-05-31  2020-05-31 02:02:27         Full
#
#       Outcome Backup re-run Reason Final outcome
# 0     Success           NaN    NaN           NaN
# ...

# %%
path = "./Office_work/EMEA"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

SL44_EMEA_TSM = pd.DataFrame()

for file in files:
    current_data = pd.read_excel(path+"/"+file,0)
    SL44_EMEA_TSM = pd.concat([SL44_EMEA_TSM, current_data])

# %%
SL44_EMEA_TSM
# Out:
#             BackupServer  BackupDay        StartDateTime  \
# 0   FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 20:00:55
# 1   FBSIBAK003.FDNET.COM 2020-05-01  2020-05-01 03:30:15
# 2   FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 23:30:20
# 3   FBSIBAK003.FDNET.COM 2020-05-01  2020-04-30 23:30:21
# 4   FBSIBAK003.FDNET.COM 2020-05-01  2020-05-01 03:30:07
# ..                   ...        ...                  ...
# 50  FBSIBAK003.FDNET.COM 2020-05-31  2020-05-31 06:01:21
# 51  FBSIBAK003.FDNET.COM 2020-05-31  2020-05-30 18:00:36
# 52  FBSIBAK003.FDNET.COM 2020-05-31  2020-05-31 06:01:24
# 53  FBSIBAK003.FDNET.COM 2020-05-31  2020-05-31 06:02:29
# 54  FBSIBAK003.FDNET.COM 2020-05-31  2020-05-31 06:03:26
#
#                                GroupName Duration(HH:MM:SS)       ClientName  \
# 0   UNIX_DOMAIN.UNIX_NIGHTLY_INCREMENTAL           00:00:06       fbppnss002
# 1   NOTESMAIL_DOMAIN.NOTESMAIL_TDP_B_ARC           00:00:07  fbsplnm102b_tdp
# ...

# %%
SL44_EMEA_TSM.drop(['GroupName','Duration(HH:MM:SS)','DataTransferredKB','Performance(MB/sec)'],axis=1,inplace=True)

# %%
SL44_EMEA_TSM.rename(columns={'BackupServer':'BackupServer','BackupDay':'BackupDay','StartDateTime':'StartDate','ClientName':'ClientName','Outcome':'BackupStatus','Backup re-run':'Backup Rerun(Y/N)','Reason':'Reason for the Backup Failures','Final outcome':'Backup Final Outcome'},inplace=True)

# %%
SL44_EMEA_TSM.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'Level',
#        'BackupStatus', 'Backup Rerun(Y/N)', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_APAC_FINAL = pd.concat([SL44_APAC_TSM,SL44_APAC_AVAMAR],ignore_index=True)

# %%
SL44_APAC_FINAL.to_excel("SL44_APAC_FINAL.xlsx",index=False)

# %%
SL44_EMEA_TSM.shape
# Out:
# (7140, 9)

# %%
SL44_EMEA_AVAMAR.shape
# Out:
# (2482, 9)

# %%
SL44_EMEA_FINAL.shape
# Out:
# (9622, 9)

# %%
SL44_RG_FINAL = pd.read_excel('SL44_RG_FINAL.xls')

# %%
SL44_RG_FINAL['Level']='Incremental'

# %%
SL44_RG_FINAL
# Out:
#                BackupServer            BackupDay  \
# 0                RGSIBAK004           01-05-2020
# 1                RGSIBAK004           01-05-2020
# 2                RGSIBAK004           01-05-2020
# 3                RGSIBAK004           01-05-2020
# 4                RGSIBAK004           01-05-2020
# ...                     ...                  ...
# 19852  RGPIAUN003.FDNET.COM  2020-05-31 00:00:00
# 19853  RGPIAUN003.FDNET.COM  2020-05-31 00:00:00
# 19854  RGPIAUN003.FDNET.COM  2020-05-31 00:00:00
# 19855  RGPIAUN003.FDNET.COM  2020-05-31 00:00:00
# 19856  RGPIAUN003.FDNET.COM  2020-05-31 00:00:00
#
#                           StartDate            ClientName  \
# 0               2020-04-30 06:40:29            RGBPLNM110
# 1               2020-04-30 06:53:07            RGPIAPP037
# 2               2020-04-30 15:32:38            RGPIISD001
# 3               2020-04-30 18:00:08            RGPPFTP005
# 4               2020-04-30 18:00:02            RGPQWEB069
# ...

# %%
SL44_APAC_FINAL.to_excel("SL44_APAC_FINAL.xls", index=False)

# %%
SL44_NA_FINAL = pd.read_excel('SL44_NA_FINAL.xls')

# %%
SL44_NA_FINAL['Level'] = 'Incremental'

# %%
SL44_NA_FINAL.to_excel("SL44_NA_FINAL.xls", index=False)

# %%
SL44_NA_FINAL
# Out:
#               BackupServer            BackupDay                     StartDate  \
# 0               LBSIBAK002           01-05-2020    2020-04-30 20:31:12.000000
# 1               LBSIBAK002           01-05-2020    2020-04-30 20:30:29.000000
# 2               LBSIBAK002           01-05-2020    2020-04-30 21:31:00.000000
# 3               LBSIBAK002           01-05-2020    2020-04-30 22:31:05.000000
# 4               CASIBAK003           01-05-2020    2020-04-30 16:30:04.000000
# ...                    ...                  ...                           ...
# 8508  NBPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:30:02 NDT 2020
# 8509  NBPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:30:02 NDT 2020
# 8510  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:03 PET 2020
# 8511  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:02 PET 2020
# 8512  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:03 PET 2020
#
# ...

# %%
SL44_APAC_TSM = pd.read_excel("SL44_APAC_TSM.xls")

# %%
SL44_APAC_AVAMAR = pd.read_excel("SL44_APAC_AVAMAR.xls")

# %%
SL44_FLOUR_FINAL = pd.concat([SL44_SA_FINAL,SL44_NA_FINAL,SL44_RG_FINAL,SL44_APAC_FINAL],ignore_index=True)

# %%
SL44_SA_FINAL['Level'] = 'Incremental'

# %%
SL44_FLOUR_FINAL.to_excel("SL44_FLOUR_FINAL.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     628         try:
# --> 629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     630                                 allowZip64=self.allow_zip64)
#
# ...

# %%
SL44_FLOUR_FINAL
# Out:
#                BackupServer            BackupDay  \
# 0                SJSIMSS002           01-05-2020
# 1                SJSIMSS002           01-05-2020
# 2                SJSIMSS002           01-05-2020
# 3                SJSIMSS002           01-05-2020
# 4                SJSIMSS002           01-05-2020
# ...                     ...                  ...
# 38029  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00
# 38030  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00
# 38031  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00
# 38032  SGPIAUN001.FDNET.COM  2020-06-01 00:00:00
# 38033  JKPIAUN001.FDNET.COM  2020-05-31 00:00:00
#
#                           StartDate            ClientName  \
# 0               2020-04-30 20:00:40        SJPPVOC002-NEW
# 1               2020-04-30 20:00:45         SJPPLND003_OS
# 2               2020-04-30 20:00:27            SJPPSUS004
# 3               2020-04-30 20:01:01            SJSIMSS002
# 4               2020-04-30 20:00:22            SJPPDCX001
# ...

# %%
SL44_SA_TSM = pd.read_excel('SL44_SA_TSM.xls')

# %%
SL44_SA_AVAMAR = pd.read_excel('SL44_SA_AVAMAR.xls')

# %%
SL44_SA_FINAL.shape
# Out:
# (2262, 10)

# %%
SL44_NA_FINAL.shape
# Out:
# (8513, 10)

# %%
SL44_APAC_FINAL.shape
# Out:
# (7402, 11)

# %%
SL44_RG_FINAL.shape
# Out:
# (19857, 11)

# %%
SL44_APAC_FINAL
# Out:
#               BackupServer            BackupDay                     StartDate  \
# 0               PESIBAK003           01-05-2020           2020-04-30 17:01:04
# 1               PESIBAK003           01-05-2020           2020-04-30 17:00:44
# 2               PESIBAK003           01-05-2020           2020-04-30 17:00:38
# 3               PESIBAK003           01-05-2020           2020-04-30 17:01:01
# 4               PESIBAK003           01-05-2020           2020-04-30 17:00:18
# ...                    ...                  ...                           ...
# 7397  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:02 SGT 2020
# 7398  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:07:17 SGT 2020
# 7399  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:02 SGT 2020
# 7400  SGPIAUN001.FDNET.COM  2020-06-01 00:00:00  Sun May 31 01:31:37 SGT 2020
# 7401  JKPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:18 WIB 2020
#
# ...

# %%
SL44_NA_FINAL
# Out:
#               BackupServer            BackupDay                     StartDate  \
# 0               LBSIBAK002           01-05-2020    2020-04-30 20:31:12.000000
# 1               LBSIBAK002           01-05-2020    2020-04-30 20:30:29.000000
# 2               LBSIBAK002           01-05-2020    2020-04-30 21:31:00.000000
# 3               LBSIBAK002           01-05-2020    2020-04-30 22:31:05.000000
# 4               CASIBAK003           01-05-2020    2020-04-30 16:30:04.000000
# ...                    ...                  ...                           ...
# 8508  NBPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:30:02 NDT 2020
# 8509  NBPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:30:02 NDT 2020
# 8510  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:03 PET 2020
# 8511  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:02 PET 2020
# 8512  LVPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 17:00:03 PET 2020
#
# ...

# %%
SL44_APAC_TSM
# Out:
#      BackupServer   BackupDay                   StartDate          ClientName  \
# 0      PESIBAK003  01-05-2020         2020-04-30 17:01:04          PESIBAK004
# 1      PESIBAK003  01-05-2020         2020-04-30 17:00:44          PEPIURL001
# 2      PESIBAK003  01-05-2020         2020-04-30 17:00:38          PEPPTIF001
# 3      PESIBAK003  01-05-2020         2020-04-30 17:01:01          PEPPISO001
# 4      PESIBAK003  01-05-2020         2020-04-30 17:00:18          PEPPFIL018
# ...           ...         ...                         ...                 ...
# 4898   UNSIMSS001  31-05-2020  2020-05-30 21:00:00.000000          UNSIMSS001
# 4899   MLSIBAK002  31-05-2020         2020-05-30 20:00:40      MLSPARC001-NEW
# 4900   MLSIBAK002  31-05-2020  2020-05-30 20:00:00.000000          MLSPARC002
# 4901   MLSIBAK002  31-05-2020  2020-05-31 01:00:00.000000     MLSPLNM005_DAOS
# 4902   MLSIBAK002  31-05-2020  2020-05-31 01:00:00.000000  MLSPLNM006_OS_DAOS
#
# ...

# %%
SL44_APAC_AVAMAR
# Out:
#               BackupServer  BackupDay                      StartDate  \
# 0     MEPIAUN001.FDNET.COM 2020-05-01  Thu Apr 30 17:00:04 AEST 2020
# 1     MEPIAUN001.FDNET.COM 2020-05-01  Thu Apr 30 17:00:04 AEST 2020
# 2     FCPIAUN001.FDNET.COM 2020-05-01   Thu Apr 30 18:00:03 CST 2020
# 3     FCPIAUN001.FDNET.COM 2020-05-01   Thu Apr 30 18:00:03 CST 2020
# 4     FCPIAUN001.FDNET.COM 2020-05-01   Thu Apr 30 18:00:03 CST 2020
# ...                    ...        ...                            ...
# 2494  SGPIAUN001.FDNET.COM 2020-05-31   Sat May 30 19:00:02 SGT 2020
# 2495  SGPIAUN001.FDNET.COM 2020-05-31   Sat May 30 19:07:17 SGT 2020
# 2496  SGPIAUN001.FDNET.COM 2020-05-31   Sat May 30 19:00:02 SGT 2020
# 2497  SGPIAUN001.FDNET.COM 2020-06-01   Sun May 31 01:31:37 SGT 2020
# 2498  JKPIAUN001.FDNET.COM 2020-05-31   Sat May 30 19:00:18 WIB 2020
#
#                 ClientName                        BackupStatus  \
# 0     meppdcx002.fdnet.com    Activity completed successfully.
# ...

# %%
SL44_APAC_AVAMAR.rename(columns={'Backup re-run(Y/N)':'Backup Rerun(Y/N)'},inplace=True)

# %%
SL44_APAC_TSM.rename(columns={'Backup re-run(Y/N)':'Backup Rerun(Y/N)'},inplace=True)

# %%
SL44_APAC_TSM
# Out:
#      BackupServer   BackupDay                   StartDate          ClientName  \
# 0      PESIBAK003  01-05-2020         2020-04-30 17:01:04          PESIBAK004
# 1      PESIBAK003  01-05-2020         2020-04-30 17:00:44          PEPIURL001
# 2      PESIBAK003  01-05-2020         2020-04-30 17:00:38          PEPPTIF001
# 3      PESIBAK003  01-05-2020         2020-04-30 17:01:01          PEPPISO001
# 4      PESIBAK003  01-05-2020         2020-04-30 17:00:18          PEPPFIL018
# ...           ...         ...                         ...                 ...
# 4898   UNSIMSS001  31-05-2020  2020-05-30 21:00:00.000000          UNSIMSS001
# 4899   MLSIBAK002  31-05-2020         2020-05-30 20:00:40      MLSPARC001-NEW
# 4900   MLSIBAK002  31-05-2020  2020-05-30 20:00:00.000000          MLSPARC002
# 4901   MLSIBAK002  31-05-2020  2020-05-31 01:00:00.000000     MLSPLNM005_DAOS
# 4902   MLSIBAK002  31-05-2020  2020-05-31 01:00:00.000000  MLSPLNM006_OS_DAOS
#
# ...

# %%
SL44_APAC_FINAL
# Out:
#               BackupServer            BackupDay                     StartDate  \
# 0               PESIBAK003           01-05-2020           2020-04-30 17:01:04
# 1               PESIBAK003           01-05-2020           2020-04-30 17:00:44
# 2               PESIBAK003           01-05-2020           2020-04-30 17:00:38
# 3               PESIBAK003           01-05-2020           2020-04-30 17:01:01
# 4               PESIBAK003           01-05-2020           2020-04-30 17:00:18
# ...                    ...                  ...                           ...
# 7397  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:02 SGT 2020
# 7398  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:07:17 SGT 2020
# 7399  SGPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:02 SGT 2020
# 7400  SGPIAUN001.FDNET.COM  2020-06-01 00:00:00  Sun May 31 01:31:37 SGT 2020
# 7401  JKPIAUN001.FDNET.COM  2020-05-31 00:00:00  Sat May 30 19:00:18 WIB 2020
#
# ...

# %%
SL44_APAC_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_APAC_TSM.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_APAC_FINAL = pd.concat([SL44_APAC_AVAMAR,SL44_APAC_TSM],ignore_index=True)

# %%
SL44_APAC_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_APAC_FINAL.to_excel("SL44_APAC_FINAL.xlsx",index=False)

# %%
SL44_APAC_FINAL
# Out:
#               BackupServer            BackupDay  \
# 0     MEPIAUN001.FDNET.COM  2020-05-01 00:00:00
# 1     MEPIAUN001.FDNET.COM  2020-05-01 00:00:00
# 2     FCPIAUN001.FDNET.COM  2020-05-01 00:00:00
# 3     FCPIAUN001.FDNET.COM  2020-05-01 00:00:00
# 4     FCPIAUN001.FDNET.COM  2020-05-01 00:00:00
# ...                    ...                  ...
# 7397            UNSIMSS001           31-05-2020
# 7398            MLSIBAK002           31-05-2020
# 7399            MLSIBAK002           31-05-2020
# 7400            MLSIBAK002           31-05-2020
# 7401            MLSIBAK002           31-05-2020
#
#                           StartDate            ClientName  \
# 0     Thu Apr 30 17:00:04 AEST 2020  meppdcx002.fdnet.com
# 1     Thu Apr 30 17:00:04 AEST 2020  meppfnp001.fdnet.com
# 2      Thu Apr 30 18:00:03 CST 2020  fcppdba012.fdnet.com
# 3      Thu Apr 30 18:00:03 CST 2020  fcppdba014.fdnet.com
# 4      Thu Apr 30 18:00:03 CST 2020  fcppdba017.fdnet.com
# ...

# %%
SL44_RG_TSM = pd.read_excel('SL44_RG_TSM.xls')

# %%
SL44_RG_AVAMAR = pd.read_excel('SL44_RG_AVAMAR.xls')

# %%
SL44_RG_TSM.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        ' Backup re-run(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'Client Name', 'Backup Status',
#        'Backup Rerun (Y/N)', 'Incident', 'Failures', 'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.rename(columns={'Backup Rerun (Y/N)':'Backup Rerun(Y/N)'},inplace=True)

# %%
SL44_RG_TSM.rename(columns={'Backup re-run(Y/N)':'Backup Rerun(Y/N)'},inplace=True)

# %%
SL44_RG_TSM.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        ' Backup re-run(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'Client Name', 'Backup Status',
#        'Backup Rerun(Y/N)', 'Incident', 'Failures', 'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_TSM = pd.read_excel('SL44_RG_TSM.xls')

# %%
SL44_RG_TSM.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
set(SL44_APAC_FINAL.columns) - set(SL44_SA_FINAL.columns)
# Out:
# set()

# %%
SL44_APAC_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'Client Name', 'Backup Status',
#        'Backup Rerun(Y/N)', 'Incident', 'Failures', 'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_AVAMAR=pd.read_excel('SL44_RG_AVAMAR1.xls')

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['Site_Code', 'Server Name', 'SLA Date', 'Actual Start Time',
#        'Backup Type', 'Client Name', 'Backup Status', 'Backup Rerun (Y/N)',
#        'Incident', 'Failures', 'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.drop(['Site_Code','Backup Type'],axis=1,inplace=True)

# %%
SL44_RG_AVAMAR.rename(columns={'Backup Rerun (Y/N)':'Backup Rerun(Y/N)'},inplace=True)

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['Server Name', 'SLA Date', 'Actual Start Time', 'Client Name',
#        'Backup Status', 'Backup Rerun(Y/N)', 'Incident', 'Failures',
#        'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.rename(columns={'Server Name':'BackupServer'},inplace=True)

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['BackupServer', 'SLA Date', 'Actual Start Time', 'Client Name',
#        'Backup Status', 'Backup Rerun(Y/N)', 'Incident', 'Failures',
#        'Backup Final Result'],
#       dtype='object')

# %%
SL44_RG_AVAMAR.rename(columns={'Actual Start Time':'StartDate', 'SLA Date':'BackupDay', 'Failures':'Reason for the Backup Failures','Backup Final Result':'Backup Final Outcome','Client Name':'ClientName', 'Backup Status':'BackupStatus',},inplace=True)

# %%
SL44_RG_AVAMAR.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_RG_FINAL = pd.concat(['SL44_RG_TSM','SL44_RG_AVAMAR'],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-bb9c016f4ae7> in <module>
# ----> 1 SL44_RG_FINAL = pd.concat(['SL44_RG_TSM','SL44_RG_AVAMAR'],ignore_index=True)
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     355                     "only Series and DataFrame objs are valid".format(typ=type(obj))
#     356                 )
# ...

# %%
SL44_RG_FINAL = pd.concat([SL44_RG_AVAMAR,SL44_RG_TSM],ignore_index=True)

# %%
SL44_RG_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_RG_FINAL.to_excel("SL44_RG_FINAL.xlsx",index=False)

# %%
SL44_NA_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome', 'Level'],
#       dtype='object')

# %%
SL44_SA_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome', 'Level'],
#       dtype='object')

# %%
SL44_SA_FINAL = pd.read_excel('SL44_SA_FINAL.xls')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-234-150c4b74c53e> in <module>
# ----> 1 SL44_SA_FINAL = pd.read_excel('SL44_SA_FINAL.xls')
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# E:\Movies\tollywood\Anaconda\envs\pandas_playground\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
# ...

# %%
SL44_SA_FINAL = pd.read_excel('SL44_SA_FINAL.xlsx')

# %%
SL44_SA_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_NA_FINAL = pd.read_excel('SL44_NA_FINAL.xls')

# %%
SL44_NA_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_FLOUR_FINAL = pd.concat([SL44_APAC_FINAL,SL44_RG_FINAL,SL44_NA_FINAL,SL44_SA_FINAL],ignore_index=True)

# %%
SL44_FLOUR_FINAL.columns
# Out:
# Index(['BackupServer', 'BackupDay', 'StartDate', 'ClientName', 'BackupStatus',
#        'Backup Rerun(Y/N)', 'Incident', 'Reason for the Backup Failures',
#        'Backup Final Outcome'],
#       dtype='object')

# %%
SL44_FLOUR_FINAL.to_excel("SL44_FLOUR_FINAL.xlsx",index=False)
